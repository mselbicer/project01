# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 


df = pd.read_csv('flights.csv')
# Out:
# C:\Users\mselbicer\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df.shape
# Out:
# (5819079, 31)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
df.info(null_counts=all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   YEAR                 5819079 non-null  int64
#  1   MONTH                5819079 non-null  int64
#  2   DAY                  5819079 non-null  int64
#  3   DAY_OF_WEEK          5819079 non-null  int64
#  4   AIRLINE              5819079 non-null  object
#  5   FLIGHT_NUMBER        5819079 non-null  int64
#  6   TAIL_NUMBER          5804358 non-null  object
#  7   ORIGIN_AIRPORT       5819079 non-null  object
#  8   DESTINATION_AIRPORT  5819079 non-null  object
#  9   SCHEDULED_DEPARTURE  5819079 non-null  int64
#  10  DEPARTURE_TIME       5732926 non-null  float64
#  11  DEPARTURE_DELAY      5732926 non-null  float64
#  12  TAXI_OUT             5730032 non-null  float64
#  13  WHEELS_OFF           5730032 non-null  float64
# ...

# %%
df.iloc[2343:2380,9:25]
# Out:
#       SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  \
# 2343                  851           858.0              7.0      16.0
# 2344                  851           908.0             17.0      10.0
# 2345                  851           849.0             -2.0      22.0
# 2346                  852           855.0              3.0       6.0
# 2347                  852           906.0             14.0      27.0
# 2348                  852           851.0             -1.0      19.0
# 2349                  853           908.0             15.0      11.0
# 2350                  853           903.0             10.0      10.0
# 2351                  854           853.0             -1.0      16.0
# 2352                  854           855.0              1.0      12.0
# 2353                  854           852.0             -2.0      20.0
# 2354                  854           847.0             -7.0      14.0
# 2355                  854           856.0              2.0      16.0
# ...

# %%
df.iloc[2343:2380,24:31]
# Out:
#       CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 2343          0                 NaN               NaN             NaN
# 2344          0                 NaN               NaN             NaN
# 2345          0                 NaN               NaN             NaN
# 2346          0                 NaN               NaN             NaN
# 2347          0                 NaN               NaN             NaN
# 2348          0                 NaN               NaN             NaN
# 2349          0                 NaN               1.0             0.0
# 2350          0                 NaN               NaN             NaN
# 2351          0                 NaN               NaN             NaN
# 2352          0                 NaN               NaN             NaN
# 2353          0                 NaN               NaN             NaN
# 2354          0                 NaN               NaN             NaN
# ...

# %%
df.loc[df.DIVERTED >0]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 724      2015      1    1            4      DL            716      N944DL
# 1455     2015      1    1            4      OO           5237      N712SK
# 2218     2015      1    1            4      WN           1966      N685SW
# 2526     2015      1    1            4      EV           4555      N12552
# 2866     2015      1    1            4      WN           1081      N214WN
# ...       ...    ...  ...          ...     ...            ...         ...
# 5813860  2015     12   31            4      UA           1291      N596UA
# 5815052  2015     12   31            4      EV           2785      N684JW
# 5816657  2015     12   31            4      UA            291      N76505
# 5817342  2015     12   31            4      MQ           3060      N648MQ
# 5818160  2015     12   31            4      WN           5296      N419WN
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
df.loc[df.CANCELLED >0].count()
# Out:
# YEAR                   89884
# MONTH                  89884
# DAY                    89884
# DAY_OF_WEEK            89884
# AIRLINE                89884
# FLIGHT_NUMBER          89884
# TAIL_NUMBER            75163
# ORIGIN_AIRPORT         89884
# DESTINATION_AIRPORT    89884
# SCHEDULED_DEPARTURE    89884
# DEPARTURE_TIME          3731
# DEPARTURE_DELAY         3731
# TAXI_OUT                 837
# WHEELS_OFF               837
# SCHEDULED_TIME         89879
# ELAPSED_TIME               0
# AIR_TIME                   0
# DISTANCE               89884
# WHEELS_ON                  0
# TAXI_IN                    0
# SCHEDULED_ARRIVAL      89884
# ARRIVAL_TIME               0
# ARRIVAL_DELAY              0
# DIVERTED               89884
# CANCELLED              89884
# CANCELLATION_REASON    89884
# AIR_SYSTEM_DELAY           0
# SECURITY_DELAY             0
# AIRLINE_DELAY              0
# LATE_AIRCRAFT_DELAY        0
# WEATHER_DELAY              0
# dtype: int64

# %%
df.DAY_OF_WEEK.unique()
# 01.01.2015 (Thursday) = 4(DoW) so 1=Monday, 2=Tuesday, ...
# Out:
# array([4, 5, 6, 7, 1, 2, 3], dtype=int64)

# %%
df.DIVERTED.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.DIVERTED.value_counts()
# Out:
# 0    5803892
# 1      15187
# Name: DIVERTED, dtype: int64

# %%
df.CANCELLED.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.CANCELLED.value_counts()
# Out:
# 0    5729195
# 1      89884
# Name: CANCELLED, dtype: int64

# %%
df.CANCELLATION_REASON.unique()
# Out:
# array([nan, 'A', 'B', 'C', 'D'], dtype=object)

# %%
df.CANCELLATION_REASON.isnull().sum()
# Out:
# 5729195

# %%
cancel_reason = df.CANCELLATION_REASON.value_counts()
#Reason for Cancellation of flight: A - Airline/Carrier; B - Weather; C - National Air System; D - Security
cancel_reason
# Out:
# B    48851
# A    25262
# C    15749
# D       22
# Name: CANCELLATION_REASON, dtype: int64

# %%
df.AIRLINE_DELAY[df.AIRLINE_DELAY>0].value_counts().sum()
# Out:
# 570022

# %%
df.AIR_SYSTEM_DELAY.value_counts()
# Out:
# 0.0       498613
# 1.0        28003
# 15.0       23199
# 2.0        22981
# 3.0        21446
#            ...
# 482.0          1
# 481.0          1
# 478.0          1
# 477.0          1
# 1101.0         1
# Name: AIR_SYSTEM_DELAY, Length: 570, dtype: int64

# %%
df.loc[::,'AIR_SYSTEM_DELAY'].sort_values()
# Out:
# 4828681    0.0
# 3150394    0.0
# 1690214    0.0
# 3150397    0.0
# 1690191    0.0
#           ...
# 5819074    NaN
# 5819075    NaN
# 5819076    NaN
# 5819077    NaN
# 5819078    NaN
# Name: AIR_SYSTEM_DELAY, Length: 5819079, dtype: float64

# %%
df.groupby(['AIR_SYSTEM_DELAY']).count().sort_values('AIR_SYSTEM_DELAY')
# Out:
#                     YEAR   MONTH     DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# AIR_SYSTEM_DELAY
# 0.0               498613  498613  498613       498613   498613         498613
# 1.0                28003   28003   28003        28003    28003          28003
# 2.0                22981   22981   22981        22981    22981          22981
# 3.0                21446   21446   21446        21446    21446          21446
# 4.0                20305   20305   20305        20305    20305          20305
# ...                  ...     ...     ...          ...      ...            ...
# 916.0                  1       1       1            1        1              1
# 991.0                  1       1       1            1        1              1
# 1049.0                 1       1       1            1        1              1
# 1101.0                 1       1       1            1        1              1
# 1134.0                 1       1       1            1        1              1
#
# ...

# %%
un_delay = df.groupby(['AIR_SYSTEM_DELAY']).count().sort_values('AIR_SYSTEM_DELAY')
un_delay
# Out:
#                     YEAR   MONTH     DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# AIR_SYSTEM_DELAY
# 0.0               498613  498613  498613       498613   498613         498613
# 1.0                28003   28003   28003        28003    28003          28003
# 2.0                22981   22981   22981        22981    22981          22981
# 3.0                21446   21446   21446        21446    21446          21446
# 4.0                20305   20305   20305        20305    20305          20305
# ...                  ...     ...     ...          ...      ...            ...
# 916.0                  1       1       1            1        1              1
# 991.0                  1       1       1            1        1              1
# 1049.0                 1       1       1            1        1              1
# 1101.0                 1       1       1            1        1              1
# 1134.0                 1       1       1            1        1              1
#
# ...

# %%
type(df.AIR_SYSTEM_DELAY)
# Out:
# pandas.core.series.Series

# %%
df.AIR_SYSTEM_DELAY.unique()
# Out:
# array([      nan, 2.500e+01, 4.300e+01, 0.000e+00, 2.000e+01, 1.700e+01,
#        1.300e+01, 7.000e+00, 2.200e+01, 1.400e+01, 4.000e+00, 6.000e+00,
#        1.600e+01, 2.700e+01, 1.200e+01, 2.000e+00, 1.500e+01, 1.800e+01,
#        3.200e+01, 8.500e+01, 3.000e+00, 5.000e+00, 8.600e+01, 5.800e+01,
#        3.500e+01, 3.400e+01, 3.300e+01, 1.100e+01, 9.000e+00, 2.600e+01,
#        2.800e+01, 4.000e+01, 2.300e+01, 1.900e+01, 2.400e+01, 9.700e+01,
#        2.900e+01, 2.100e+01, 1.000e+00, 1.000e+01, 8.000e+00, 3.000e+01,
#        6.700e+01, 4.800e+01, 6.500e+01, 3.100e+01, 4.100e+01, 4.200e+01,
#        3.900e+01, 3.600e+01, 5.100e+01, 8.100e+01, 4.600e+01, 1.640e+02,
#        5.200e+01, 8.800e+01, 4.900e+01, 4.500e+01, 3.700e+01, 5.000e+01,
#        5.400e+01, 5.900e+01, 1.380e+02, 5.300e+01, 7.200e+01, 6.800e+01,
#        7.700e+01, 6.100e+01, 6.000e+01, 4.400e+01, 3.800e+01, 7.600e+01,
#        4.700e+01, 7.300e+01, 5.700e+01, 7.400e+01, 8.700e+01, 5.600e+01,
# ...

# %%
df.AIR_SYSTEM_DELAY.count()
# Out:
# 1063439

# %%
df2 = pd.read_csv('airlines.csv')
df2
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
iatacodes = pd.merge(df,df2, left_on="AIRLINE", right_on='IATA_CODE')
iatacodes
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4        AS             98      N407AS
# 1        2015      1    1            4        AS            135      N527AS
# 2        2015      1    1            4        AS            108      N309AS
# 3        2015      1    1            4        AS            122      N413AS
# 4        2015      1    1            4        AS            130      N457AS
# ...       ...    ...  ...          ...       ...            ...         ...
# 5819074  2015     12   31            4        VX            769      N622VA
# 5819075  2015     12   31            4        VX            357      N284VA
# 5819076  2015     12   31            4        VX           1916      N853VA
# 5819077  2015     12   31            4        VX            490      N840VA
# 5819078  2015     12   31            4        VX             48      N281VA
#
# ...

# %%
iatacodes.rename(columns={'AIRLINE_y': 'AIRLINE_NAME', 'AIRLINE_x': 'IATA_CODE'}, inplace=True)
iatacodes
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK  IATA_CODE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4         AS             98      N407AS
# 1        2015      1    1            4         AS            135      N527AS
# 2        2015      1    1            4         AS            108      N309AS
# 3        2015      1    1            4         AS            122      N413AS
# 4        2015      1    1            4         AS            130      N457AS
# ...       ...    ...  ...          ...        ...            ...         ...
# 5819074  2015     12   31            4         VX            769      N622VA
# 5819075  2015     12   31            4         VX            357      N284VA
# 5819076  2015     12   31            4         VX           1916      N853VA
# 5819077  2015     12   31            4         VX            490      N840VA
# 5819078  2015     12   31            4         VX             48      N281VA
#
# ...

# %%
# create a list of our conditions
cond_climates = [
    (iatacodes['MONTH'] < 3 ) | (iatacodes['MONTH'] == 12),
    (iatacodes['MONTH'] >= 3) & (iatacodes['MONTH'] < 6),
    (iatacodes['MONTH'] >= 6) & (iatacodes['MONTH'] < 9),
    (iatacodes['MONTH'] >= 9) & (iatacodes['MONTH'] < 12)
    ]

# create a list of the values we want to assign for each condition
values_climate = ['Winter', 'Spring', 'Summer', 'Autumn']

# create a new column and use np.select to assign values to it using our lists as arguments
iatacodes['CLIMATE'] = np.select(cond_climates, values_climate)

# display updated DataFrame
iatacodes.sample(7)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK  IATA_CODE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4183898  2015      3   19            4         MQ           3620      N521MQ
# 4078331  2015     12    9            3         EV           5521      N717EV
# 3004037  2015      2    5            4         OO           3496      N699BR
# 3989340  2015     10    8            4         EV           4516      N14920
# 701959   2015     10   13            2         AA           1348      N477AA
# 1238919  2015      3    7            6         DL           1055      N313US
# 5207906  2015      7   25            6         WN           4269      N762SW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 4183898            STL                 LGA                 1655  ...
# 4078331            MSP                 SYR                 1926  ...
# 3004037            SEA                 FAT                  850  ...
# 3989340          11057               12266                 1821  ...
# ...

# %%
flight_no = iatacodes.AIRLINE_NAME.value_counts()
flight_no
# Out:
# Southwest Airlines Co.          1261855
# Delta Air Lines Inc.             875881
# American Airlines Inc.           725984
# Skywest Airlines Inc.            588353
# Atlantic Southeast Airlines      571977
# United Air Lines Inc.            515723
# American Eagle Airlines Inc.     294632
# JetBlue Airways                  267048
# US Airways Inc.                  198715
# Alaska Airlines Inc.             172521
# Spirit Air Lines                 117379
# Frontier Airlines Inc.            90836
# Hawaiian Airlines Inc.            76272
# Virgin America                    61903
# Name: AIRLINE_NAME, dtype: int64

# %%
cancels = iatacodes[iatacodes.CANCELLATION_REASON == 'A'].groupby(['AIRLINE_NAME']).CANCELLED.count()
cancels
# Out:
# AIRLINE_NAME
# Alaska Airlines Inc.             334
# American Airlines Inc.          2879
# American Eagle Airlines Inc.    2475
# Atlantic Southeast Airlines     3604
# Delta Air Lines Inc.             594
# Frontier Airlines Inc.           308
# Hawaiian Airlines Inc.           170
# JetBlue Airways                  883
# Skywest Airlines Inc.           3205
# Southwest Airlines Co.          6122
# Spirit Air Lines                 654
# US Airways Inc.                 1007
# United Air Lines Inc.           2870
# Virgin America                   157
# Name: CANCELLED, dtype: int64

# %%
cancels2 = iatacodes[iatacodes.CANCELLATION_REASON == 'B'].groupby(['AIRLINE_NAME']).CANCELLED.count()
cancels2
# Out:
# AIRLINE_NAME
# Alaska Airlines Inc.             317
# American Airlines Inc.          7306
# American Eagle Airlines Inc.    9164
# Atlantic Southeast Airlines     5082
# Delta Air Lines Inc.            2973
# Frontier Airlines Inc.           280
# Hawaiian Airlines Inc.             1
# JetBlue Airways                 2464
# Skywest Airlines Inc.           5539
# Southwest Airlines Co.          8843
# Spirit Air Lines                1068
# US Airways Inc.                 2490
# United Air Lines Inc.           3312
# Virgin America                    12
# Name: CANCELLED, dtype: int64

# %%
cancels3 = iatacodes[iatacodes.CANCELLATION_REASON == 'C'].groupby(['AIRLINE_NAME']).CANCELLED.count()
cancels3
# Out:
# AIRLINE_NAME
# Alaska Airlines Inc.              18
# American Airlines Inc.           730
# American Eagle Airlines Inc.    3385
# Atlantic Southeast Airlines     6544
# Delta Air Lines Inc.             257
# JetBlue Airways                  928
# Skywest Airlines Inc.           1216
# Southwest Airlines Co.          1066
# Spirit Air Lines                 279
# US Airways Inc.                  570
# United Air Lines Inc.            391
# Virgin America                   365
# Name: CANCELLED, dtype: int64

# %%
cancels4 = iatacodes[iatacodes.CANCELLATION_REASON == 'D'].groupby(['AIRLINE_NAME']).CANCELLED.count()
cancels4
# Out:
# AIRLINE_NAME
# American Airlines Inc.           4
# American Eagle Airlines Inc.     1
# Atlantic Southeast Airlines      1
# JetBlue Airways                  1
# Southwest Airlines Co.          12
# Spirit Air Lines                 3
# Name: CANCELLED, dtype: int64

# %%
cancel_rate = cancels/flight_no
cancel_rate.sort_values()
# Out:
# Delta Air Lines Inc.            0.000678
# Alaska Airlines Inc.            0.001936
# Hawaiian Airlines Inc.          0.002229
# Virgin America                  0.002536
# JetBlue Airways                 0.003307
# Frontier Airlines Inc.          0.003391
# American Airlines Inc.          0.003966
# Southwest Airlines Co.          0.004852
# US Airways Inc.                 0.005068
# Skywest Airlines Inc.           0.005447
# United Air Lines Inc.           0.005565
# Spirit Air Lines                0.005572
# Atlantic Southeast Airlines     0.006301
# American Eagle Airlines Inc.    0.008400
# dtype: float64

# %%
delays_airline = iatacodes[iatacodes.AIRLINE_DELAY  > 0].groupby(['AIRLINE_NAME']).AIRLINE_DELAY.count()
delays_airline
# Out:
# AIRLINE_NAME
# Alaska Airlines Inc.              8363
# American Airlines Inc.           68656
# American Eagle Airlines Inc.     27236
# Atlantic Southeast Airlines      53943
# Delta Air Lines Inc.             63128
# Frontier Airlines Inc.           11517
# Hawaiian Airlines Inc.            7395
# JetBlue Airways                  38665
# Skywest Airlines Inc.            39127
# Southwest Airlines Co.          144524
# Spirit Air Lines                 17307
# US Airways Inc.                  19717
# United Air Lines Inc.            65999
# Virgin America                    4445
# Name: AIRLINE_DELAY, dtype: int64

# %%
df.AIRLINE_DELAY[df.AIRLINE_DELAY>0].value_counts().sum()    #for checking
# Out:
# 570022

# %%
delays = iatacodes[iatacodes.AIRLINE_DELAY + iatacodes.LATE_AIRCRAFT_DELAY  > 0].groupby(['AIRLINE_NAME']).AIRLINE_DELAY.count()
delays
# Out:
# AIRLINE_NAME
# Alaska Airlines Inc.             14643
# American Airlines Inc.           97063
# American Eagle Airlines Inc.     45726
# Atlantic Southeast Airlines      86474
# Delta Air Lines Inc.             85141
# Frontier Airlines Inc.           18167
# Hawaiian Airlines Inc.            8410
# JetBlue Airways                  47570
# Skywest Airlines Inc.            86503
# Southwest Airlines Co.          209247
# Spirit Air Lines                 22442
# US Airways Inc.                  26199
# United Air Lines Inc.            81709
# Virgin America                    7786
# Name: AIRLINE_DELAY, dtype: int64

# %%
delay_rate = delays/flight_no
delay_rate.sort_values()
# Out:
# Alaska Airlines Inc.            0.084877
# Delta Air Lines Inc.            0.097206
# Hawaiian Airlines Inc.          0.110263
# Virgin America                  0.125777
# US Airways Inc.                 0.131842
# American Airlines Inc.          0.133699
# Skywest Airlines Inc.           0.147026
# Atlantic Southeast Airlines     0.151184
# American Eagle Airlines Inc.    0.155197
# United Air Lines Inc.           0.158436
# Southwest Airlines Co.          0.165825
# JetBlue Airways                 0.178133
# Spirit Air Lines                0.191193
# Frontier Airlines Inc.          0.199998
# dtype: float64

# %%
cancel_rate + delay_rate
# Out:
# Alaska Airlines Inc.            0.086813
# American Airlines Inc.          0.137664
# American Eagle Airlines Inc.    0.163597
# Atlantic Southeast Airlines     0.157485
# Delta Air Lines Inc.            0.097884
# Frontier Airlines Inc.          0.203389
# Hawaiian Airlines Inc.          0.112492
# JetBlue Airways                 0.181439
# Skywest Airlines Inc.           0.152473
# Southwest Airlines Co.          0.170677
# Spirit Air Lines                0.196764
# US Airways Inc.                 0.136910
# United Air Lines Inc.           0.164001
# Virgin America                  0.128314
# dtype: float64

# %%
(cancel_rate + delay_rate).plot(kind='bar',grid=True, color='b')

plt.title('Airlines & Delay + Cancellation Rates');
# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
plt.savefig("output1.svg",bbox_inches='tight')

# %%
flights_port = iatacodes.groupby(['AIRLINE_NAME', 'ORIGIN_AIRPORT'])['ORIGIN_AIRPORT'].count()
df.flights_port = pd.DataFrame(flights_port)
df.flights_port
# Out:
#                                      ORIGIN_AIRPORT
# AIRLINE_NAME         ORIGIN_AIRPORT
# Alaska Airlines Inc. 10140                       29
#                      10165                        9
#                      10170                       29
#                      10299                      934
#                      10397                       58
# ...                                             ...
# Virgin America       PSP                        211
#                      SAN                       1742
#                      SEA                       2128
#                      SFO                      15940
#                      TUL                          1
#
# [3437 rows x 1 columns]

# %%
# According to Climate

# %%
flights_cli = iatacodes.groupby(['CLIMATE', 'AIRLINE_NAME'])['YEAR'].count()
df.flights_cli = pd.DataFrame(flights_cli)
df.flights_cli
df_f_cli = df.flights_cli.add_suffix('_Count').reset_index()
df_f_cli
# Out:
# <ipython-input-17-33ba178baedc>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.flights_cli = pd.DataFrame(flights_cli)
#    CLIMATE                  AIRLINE_NAME  YEAR_Count
# 0   Autumn          Alaska Airlines Inc.       42688
# 1   Autumn        American Airlines Inc.      224540
# 2   Autumn  American Eagle Airlines Inc.       63489
# 3   Autumn   Atlantic Southeast Airlines      132021
# 4   Autumn          Delta Air Lines Inc.      219843
# 5   Autumn        Frontier Airlines Inc.       23737
# 6   Autumn        Hawaiian Airlines Inc.       18420
# 7   Autumn               JetBlue Airways       64743
# 8   Autumn         Skywest Airlines Inc.      143725
# 9   Autumn        Southwest Airlines Co.      309206
# 10  Autumn              Spirit Air Lines       30320
# 11  Autumn         United Air Lines Inc.      130319
# ...

# %%
fl_cli = sns.barplot(x="AIRLINE_NAME", y="YEAR_Count", hue="CLIMATE", 
                     data=df_f_cli, palette="Blues_d", )
fl_cli.set_xticklabels(fl_cli.get_xticklabels(), rotation=90);
fl_cli.set_xlabel('Airlines', fontsize=15)
fl_cli.set_ylabel('Flight No', fontsize=15);

# %%
cancels_cli = iatacodes[iatacodes.CANCELLATION_REASON == 'A'].groupby(['CLIMATE','AIRLINE_NAME']).CANCELLED.count()
cancels_cli
# Out:
# CLIMATE  AIRLINE_NAME
# Autumn   Alaska Airlines Inc.              52
#          American Airlines Inc.           642
#          American Eagle Airlines Inc.     142
#          Atlantic Southeast Airlines      419
#          Delta Air Lines Inc.              20
#          Frontier Airlines Inc.            35
#          Hawaiian Airlines Inc.            41
#          JetBlue Airways                  154
#          Skywest Airlines Inc.            368
#          Southwest Airlines Co.           866
#          Spirit Air Lines                  84
#          United Air Lines Inc.            259
#          Virgin America                    44
# Spring   Alaska Airlines Inc.              98
#          American Airlines Inc.           556
#          American Eagle Airlines Inc.     578
#          Atlantic Southeast Airlines     1041
#          Delta Air Lines Inc.             185
#          Frontier Airlines Inc.            68
#          Hawaiian Airlines Inc.            31
# ...

# %%
cancels_cli_rate = cancels_cli/flights_cli
df_cancels_cli_rate = pd.DataFrame(cancels_cli_rate)
df_cancels_cli_rate
# Out:
#                                              0
# CLIMATE AIRLINE_NAME
# Autumn  Alaska Airlines Inc.          0.001218
#         American Airlines Inc.        0.002859
#         American Eagle Airlines Inc.  0.002237
#         Atlantic Southeast Airlines   0.003174
#         Delta Air Lines Inc.          0.000091
#         Frontier Airlines Inc.        0.001474
#         Hawaiian Airlines Inc.        0.002226
#         JetBlue Airways               0.002379
#         Skywest Airlines Inc.         0.002560
#         Southwest Airlines Co.        0.002801
#         Spirit Air Lines              0.002770
#         United Air Lines Inc.         0.001987
#         Virgin America                0.002745
# Spring  Alaska Airlines Inc.          0.002283
#         American Airlines Inc.        0.004105
#         American Eagle Airlines Inc.  0.007291
#         Atlantic Southeast Airlines   0.006817
#         Delta Air Lines Inc.          0.000837
# ...

# %%
delays_cli = iatacodes[iatacodes.AIRLINE_DELAY + iatacodes.LATE_AIRCRAFT_DELAY  >= 0].groupby(['CLIMATE','AIRLINE_NAME']).AIRLINE_DELAY.count()
df_delays_cli = pd.DataFrame(delays_cli)
df_delays_cli
# Out:
#                                       AIRLINE_DELAY
# CLIMATE AIRLINE_NAME
# Autumn  Alaska Airlines Inc.                   5165
#         American Airlines Inc.                31557
#         American Eagle Airlines Inc.           7837
#         Atlantic Southeast Airlines           19828
#         Delta Air Lines Inc.                  20112
#         Frontier Airlines Inc.                 4251
#         Hawaiian Airlines Inc.                 1863
#         JetBlue Airways                       11661
#         Skywest Airlines Inc.                 21338
#         Southwest Airlines Co.                40426
#         Spirit Air Lines                       6799
#         United Air Lines Inc.                 17479
#         Virgin America                         2395
# Spring  Alaska Airlines Inc.                   5059
#         American Airlines Inc.                27116
#         American Eagle Airlines Inc.          16729
#         Atlantic Southeast Airlines           28922
# ...

# %%
delays_cli_rate = delays_cli/flights_cli
df_delays_cli_rate = pd.DataFrame(delays_cli_rate)
df_delays_cli_rate
# Out:
#                                              0
# CLIMATE AIRLINE_NAME
# Autumn  Alaska Airlines Inc.          0.120994
#         American Airlines Inc.        0.140541
#         American Eagle Airlines Inc.  0.123439
#         Atlantic Southeast Airlines   0.150188
#         Delta Air Lines Inc.          0.091483
#         Frontier Airlines Inc.        0.179088
#         Hawaiian Airlines Inc.        0.101140
#         JetBlue Airways               0.180112
#         Skywest Airlines Inc.         0.148464
#         Southwest Airlines Co.        0.130741
#         Spirit Air Lines              0.224241
#         United Air Lines Inc.         0.134125
#         Virgin America                0.149389
# Spring  Alaska Airlines Inc.          0.117838
#         American Airlines Inc.        0.200198
#         American Eagle Airlines Inc.  0.211033
#         Atlantic Southeast Airlines   0.189405
#         Delta Air Lines Inc.          0.134361
# ...

# %%
total_cli=cancels_cli_rate+delays_cli_rate
df_total_cli = pd.DataFrame(total_cli)
df_total_cli 
df_dc_rate = df_total_cli.add_suffix('_Rate').reset_index()
df_dc_rate.rename(columns={'0_Rate': 'DC_Rates'}, inplace=True)
df_dc_rate
# Out:
#    CLIMATE                  AIRLINE_NAME  DC_Rates
# 0   Autumn          Alaska Airlines Inc.  0.122212
# 1   Autumn        American Airlines Inc.  0.143400
# 2   Autumn  American Eagle Airlines Inc.  0.125675
# 3   Autumn   Atlantic Southeast Airlines  0.153362
# 4   Autumn          Delta Air Lines Inc.  0.091574
# 5   Autumn        Frontier Airlines Inc.  0.180562
# 6   Autumn        Hawaiian Airlines Inc.  0.103366
# 7   Autumn               JetBlue Airways  0.182491
# 8   Autumn         Skywest Airlines Inc.  0.151025
# 9   Autumn        Southwest Airlines Co.  0.133542
# 10  Autumn              Spirit Air Lines  0.227012
# 11  Autumn         United Air Lines Inc.  0.136112
# 12  Autumn                Virgin America  0.152133
# 13  Spring          Alaska Airlines Inc.  0.120120
# 14  Spring        American Airlines Inc.  0.204303
# 15  Spring  American Eagle Airlines Inc.  0.218324
# 16  Spring   Atlantic Southeast Airlines  0.196223
# ...

# %%
df_dc_rate_plt = sns.barplot(x="AIRLINE_NAME", y="DC_Rates", hue="CLIMATE", 
                     data=df_dc_rate, palette=['Yellow','Green', 'Blue', 'Red'])
df_dc_rate_plt.set_xticklabels(fl_cli.get_xticklabels(), rotation=90)
df_dc_rate_plt.set_xlabel('Airlines', fontsize=15)
df_dc_rate_plt.set_ylabel('Delay&Canc. Rate', fontsize=15);

# %%
sp_sorted = sorted_main_table.loc[(sorted_main_table.CLIMATE=='Spring'),:].sort_values('AIRLINE_NAME').reset_index()
df_sp_sorted = pd.DataFrame(sp_sorted)
df_sp_sorted
# Out:
#     index CLIMATE                  AIRLINE_NAME  DC_Rates
# 0      13  Spring          Alaska Airlines Inc.  0.120120
# 1      14  Spring        American Airlines Inc.  0.204303
# 2      15  Spring  American Eagle Airlines Inc.  0.218324
# 3      16  Spring   Atlantic Southeast Airlines  0.196223
# 4      17  Spring          Delta Air Lines Inc.  0.135197
# 5      18  Spring        Frontier Airlines Inc.  0.290961
# 6      19  Spring        Hawaiian Airlines Inc.  0.096285
# 7      20  Spring               JetBlue Airways  0.201221
# 8      21  Spring         Skywest Airlines Inc.  0.164828
# 9      22  Spring        Southwest Airlines Co.  0.188954
# 10     23  Spring              Spirit Air Lines  0.290082
# 11     24  Spring               US Airways Inc.  0.172983
# 12     25  Spring         United Air Lines Inc.  0.211146
# 13     26  Spring                Virgin America  0.199880

# %%
import matplotlib.ticker as mtick

plt.figure(figsize=(12, 7))
sp_sorted_plt = sns.barplot(x=df_sp_sorted.AIRLINE_NAME, y=df_sp_sorted.DC_Rates, 
                     data=df_sp_sorted, palette=['limegreen']
                           )
sp_sorted_plt.set_xticklabels(fl_cli.get_xticklabels(), rotation=90)
sp_sorted_plt.set_xlabel('Airlines', fontsize=15)
sp_sorted_plt.set_ylabel('Delay+Canc. Rate', fontsize=15);
plt.title("SPRING", size=18)
sp_sorted_plt.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
for p in sp_sorted_plt.patches:
    sp_sorted_plt.annotate(format(p.get_height(), '1.2%'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'top',
                   size=12,
                   xytext = (-3, 14), 
                   textcoords = 'offset points')


plt.savefig("fig1_sp.svg",bbox_inches='tight')

# %%
su_sorted = sorted_main_table.loc[(sorted_main_table.CLIMATE=='Summer'),:].sort_values('AIRLINE_NAME').reset_index()
df_su_sorted = pd.DataFrame(su_sorted)
df_su_sorted
# Out:
#     index CLIMATE                  AIRLINE_NAME  DC_Rates
# 0      27  Summer          Alaska Airlines Inc.  0.141559
# 1      28  Summer        American Airlines Inc.  0.198363
# 2      29  Summer  American Eagle Airlines Inc.  0.206367
# 3      30  Summer   Atlantic Southeast Airlines  0.211078
# 4      31  Summer          Delta Air Lines Inc.  0.156167
# 5      32  Summer        Frontier Airlines Inc.  0.275772
# 6      33  Summer        Hawaiian Airlines Inc.  0.130522
# 7      34  Summer               JetBlue Airways  0.230185
# 8      35  Summer         Skywest Airlines Inc.  0.201871
# 9      36  Summer        Southwest Airlines Co.  0.239484
# 10     37  Summer              Spirit Air Lines  0.374236
# 11     38  Summer               US Airways Inc.  0.207376
# 12     39  Summer         United Air Lines Inc.  0.264497
# 13     40  Summer                Virgin America  0.204352

# %%
import matplotlib.ticker as mtick
plt.figure(figsize=(12, 7))
su_sorted_plt = sns.barplot(x=df_su_sorted.AIRLINE_NAME, y=df_su_sorted.DC_Rates, 
                     data=df_su_sorted, palette=['gold']
                           )
su_sorted_plt.set_xticklabels(fl_cli.get_xticklabels(), rotation=90)
su_sorted_plt.set_xlabel('Airlines', fontsize=15)
su_sorted_plt.set_ylabel('Delay+Canc. Rate', fontsize=15);
plt.title("SUMMER", size=18)
su_sorted_plt.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
for p in su_sorted_plt.patches:
    su_sorted_plt.annotate(format(p.get_height(), '1.2%'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'baseline',
                   size=12,
                   xytext = (0, 2), 
                   textcoords = 'offset points')


plt.savefig("fig2_su.svg",bbox_inches='tight')

# %%
au_sorted = sorted_main_table.loc[(sorted_main_table.CLIMATE=='Autumn'),:].sort_values('AIRLINE_NAME').reset_index()
df_au_sorted = pd.DataFrame(au_sorted)
df_au_sorted
# Out:
#     index CLIMATE                  AIRLINE_NAME  DC_Rates
# 0       0  Autumn          Alaska Airlines Inc.  0.122212
# 1       1  Autumn        American Airlines Inc.  0.143400
# 2       2  Autumn  American Eagle Airlines Inc.  0.125675
# 3       3  Autumn   Atlantic Southeast Airlines  0.153362
# 4       4  Autumn          Delta Air Lines Inc.  0.091574
# 5       5  Autumn        Frontier Airlines Inc.  0.180562
# 6       6  Autumn        Hawaiian Airlines Inc.  0.103366
# 7       7  Autumn               JetBlue Airways  0.182491
# 8       8  Autumn         Skywest Airlines Inc.  0.151025
# 9       9  Autumn        Southwest Airlines Co.  0.133542
# 10     10  Autumn              Spirit Air Lines  0.227012
# 11     11  Autumn         United Air Lines Inc.  0.136112
# 12     12  Autumn                Virgin America  0.152133

# %%
import matplotlib.ticker as mtick
plt.figure(figsize=(12, 7))
au_sorted_plt = sns.barplot(x=df_au_sorted.AIRLINE_NAME, y=df_au_sorted.DC_Rates, 
                     data=df_au_sorted, palette=['ORANGE']
                           )
au_sorted_plt.set_xticklabels(fl_cli.get_xticklabels(),  fontsize= 14,rotation=90)
au_sorted_plt.set_xlabel('Airlines', fontsize=15)
au_sorted_plt.set_ylabel('Delay+Canc. Rate', fontsize=15);
plt.title("AUTUMN", size=18)
au_sorted_plt.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
for p in au_sorted_plt.patches:
    au_sorted_plt.annotate(format(p.get_height(), '1.2%'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'baseline',
                   size=12,
                   xytext = (0, 2), 
                   textcoords = 'offset points')

plt.savefig("fig3_au.svg",bbox_inches='tight')

# %%
wi_sorted = sorted_main_table.loc[(sorted_main_table.CLIMATE=='Winter'),:].sort_values('AIRLINE_NAME').reset_index()
df_wi_sorted = pd.DataFrame(wi_sorted)
df_wi_sorted
# Out:
#     index CLIMATE                  AIRLINE_NAME  DC_Rates
# 0      41  Winter          Alaska Airlines Inc.  0.141819
# 1      42  Winter        American Airlines Inc.  0.202641
# 2      43  Winter  American Eagle Airlines Inc.  0.288528
# 3      44  Winter   Atlantic Southeast Airlines  0.225045
# 4      45  Winter          Delta Air Lines Inc.  0.159592
# 5      46  Winter        Frontier Airlines Inc.  0.311928
# 6      47  Winter        Hawaiian Airlines Inc.  0.129336
# 7      48  Winter               JetBlue Airways  0.286138
# 8      49  Winter         Skywest Airlines Inc.  0.238136
# 9      50  Winter        Southwest Airlines Co.  0.204720
# 10     51  Winter              Spirit Air Lines  0.295968
# 11     52  Winter               US Airways Inc.  0.204440
# 12     53  Winter         United Air Lines Inc.  0.220601
# 13     54  Winter                Virgin America  0.217421

# %%
import matplotlib.ticker as mtick
plt.figure(figsize=(12, 7))
wi_sorted_plt = sns.barplot(x=df_wi_sorted.AIRLINE_NAME, y=df_wi_sorted.DC_Rates, 
                     data=df_wi_sorted, palette=['skyblue']
                           )
wi_sorted_plt.set_xticklabels(fl_cli.get_xticklabels(), fontsize= 14,rotation=90)
wi_sorted_plt.set_xlabel('Airlines', fontsize=15)
wi_sorted_plt.set_ylabel('Delay+Canc. Rate', fontsize=15);
plt.title("WINTER", size=18)
wi_sorted_plt.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
for p in wi_sorted_plt.patches:
    wi_sorted_plt.annotate(format(p.get_height(), '1.2%'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'baseline',
                   size=12,
                   xytext = (0, 2), 
                   textcoords = 'offset points')
plt.savefig("fig4_wi.svg",bbox_inches='tight')

# %%
(df_total_cli.iloc[::,::])
df_total_cli.shape
# Out:
# (55, 1)

# %%
sns.pairplot(df_total_cli)

# %%
df_total_cli.plot(kind="bar",alpha=1, figsize=(20,6),color='r', grid=True)
plt.title('Cancellation & Delay Rate of Airlines // Climates');

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Filter for only certain Columns
au = iatacodes.loc[iatacodes.CLIMATE == 'Autumn', ['CLIMATE', 'AIRLINE_NAME', 'CANCELLED', 
                                              'CANCELLATION_REASON', 'AIRLINE_DELAY','LATE_AIRCRAFT_DELAY']]
au
# What happens if I try to do the same with df.iloc instead of df.loc?
# Out:
#         CLIMATE          AIRLINE_NAME  CANCELLED CANCELLATION_REASON  \
# 115374   Autumn  Alaska Airlines Inc.          0                 NaN
# 115375   Autumn  Alaska Airlines Inc.          0                 NaN
# 115376   Autumn  Alaska Airlines Inc.          0                 NaN
# 115377   Autumn  Alaska Airlines Inc.          0                 NaN
# 115378   Autumn  Alaska Airlines Inc.          0                 NaN
# ...         ...                   ...        ...                 ...
# 5813540  Autumn        Virgin America          0                 NaN
# 5813541  Autumn        Virgin America          0                 NaN
# 5813542  Autumn        Virgin America          0                 NaN
# 5813543  Autumn        Virgin America          0                 NaN
# 5813544  Autumn        Virgin America          0                 NaN
#
#          AIRLINE_DELAY  LATE_AIRCRAFT_DELAY
# 115374             NaN                  NaN
# 115375             NaN                  NaN
# ...

# %%
canc_au = au.groupby(['CANCELLATION_REASON', 'AIRLINE_NAME']).count()
df_canc_au = pd.DataFrame(canc_au)
df_canc_au
# Out:
#                                                   CLIMATE  CANCELLED  \
# CANCELLATION_REASON AIRLINE_NAME
# A                   Alaska Airlines Inc.               52         52
#                     American Airlines Inc.            642        642
#                     American Eagle Airlines Inc.      142        142
#                     Atlantic Southeast Airlines       419        419
#                     Delta Air Lines Inc.               20         20
#                     Frontier Airlines Inc.             35         35
#                     Hawaiian Airlines Inc.             41         41
#                     JetBlue Airways                   154        154
#                     Skywest Airlines Inc.             368        368
#                     Southwest Airlines Co.            866        866
#                     Spirit Air Lines                   84         84
#                     United Air Lines Inc.             259        259
# ...
